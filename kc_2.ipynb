# %% [markdown]
# # Knowledge Check 2

# %% [markdown]
# Average Restaurant Inspection Score by Zip Code

# %%
import pandas as pd


df = pd.read_csv("assets/Louisville_Metro_KY_-_Restaurant_Inspection_Scores.csv")
df.head()
# Out:
#    EstablishmentID  InspectionID Ins_TypeDesc              EstablishmentName  \
# 0            30989       1738650      REGULAR            SOUTHSIDE CHRISTIAN
# 1            30993       1662148      REGULAR               WEE CARE NURSERY
# 2            30993       1703319      REGULAR               WEE CARE NURSERY
# 3            30993       1730555      REGULAR               WEE CARE NURSERY
# 4            31043       1675318      REGULAR  KINDER CARE LEARNING CTR #424
#
#    PlaceName            Address  Address2        City State    Zip  \
# 0        NaN  5804 SOUTHSIDE DR       NaN  LOUISVILLE    KY  40214
# 1        NaN      11616 MAIN ST       NaN  LOUISVILLE    KY  40243
# 2        NaN      11616 MAIN ST       NaN  LOUISVILLE    KY  40243
# 3        NaN      11616 MAIN ST       NaN  LOUISVILLE    KY  40243
# 4        NaN   3804 KLONDIKE LN       NaN  LOUISVILLE    KY  40218
#
#                               TypeDescription          InspectionDate  score  \
# ...

# %%
import seaborn as sns


sns.catplot(x="Zip", y="score", data=df, kind="bar", height=10, aspect=2).savefig("assets/plot.png")
